# %% [markdown]
# # Data Preprocessing:

# %%
import pandas as pd
import numpy as np

# %%
# this function will na vlaues by means if it will find any continuos variable. In the case of Categorical it will fill na by
# mode values, and will skip date column without change

def fill_na_mean_median(dataframe, echo = True):
    for i in dataframe.columns:
        if(type(dataframe[i].mode()[0]) == str):
            dataframe[i]= dataframe[i].fillna(dataframe[i].mode()[0]) # fill na by median Values
            if(echo):
                print 'column name: ',i
                print type(dataframe[i][0]),': replaced with mode'
    
        else:
            dataframe[i]= dataframe[i].fillna(dataframe[i].mean()) # fill na by mean Values
            if(echo):
                print 'column name: ',i
                print type(dataframe[i][0]), ': replaced with mean'
            
    return dataframe

# %%
df_train = pd.read_csv("F:/House Pricing/data/train.csv")
df_test = pd.read_csv("F:/House Pricing/data/test.csv")

# %%
df_train.columns
# Out:
# Index([u'Id', u'MSSubClass', u'MSZoning', u'LotFrontage', u'LotArea',
#        u'Street', u'Alley', u'LotShape', u'LandContour', u'Utilities',
#        u'LotConfig', u'LandSlope', u'Neighborhood', u'Condition1',
#        u'Condition2', u'BldgType', u'HouseStyle', u'OverallQual',
#        u'OverallCond', u'YearBuilt', u'YearRemodAdd', u'RoofStyle',
#        u'RoofMatl', u'Exterior1st', u'Exterior2nd', u'MasVnrType',
#        u'MasVnrArea', u'ExterQual', u'ExterCond', u'Foundation', u'BsmtQual',
#        u'BsmtCond', u'BsmtExposure', u'BsmtFinType1', u'BsmtFinSF1',
#        u'BsmtFinType2', u'BsmtFinSF2', u'BsmtUnfSF', u'TotalBsmtSF',
#        u'Heating', u'HeatingQC', u'CentralAir', u'Electrical', u'1stFlrSF',
#        u'2ndFlrSF', u'LowQualFinSF', u'GrLivArea', u'BsmtFullBath',
#        u'BsmtHalfBath', u'FullBath', u'HalfBath', u'BedroomAbvGr',
#        u'KitchenAbvGr', u'KitchenQual', u'TotRmsAbvGrd', u'Functional',
# ...

# %%
del(df_train['Id'])
del(df_test['Id'])

# %%
df_train = fill_na_mean_median(df_train)
df_test = fill_na_mean_median(df_test)
# Out:
# column name:  MSSubClass
# <type 'numpy.int64'> : replaced with mean
# column name:  MSZoning
# <type 'str'> : replaced with mode
# column name:  LotFrontage
# <type 'numpy.float64'> : replaced with mean
# column name:  LotArea
# <type 'numpy.int64'> : replaced with mean
# column name:  Street
# <type 'str'> : replaced with mode
# column name:  Alley
# <type 'str'> : replaced with mode
# column name:  LotShape
# <type 'str'> : replaced with mode
# column name:  LandContour
# <type 'str'> : replaced with mode
# column name:  Utilities
# <type 'str'> : replaced with mode
# column name:  LotConfig
# <type 'str'> : replaced with mode
# column name:  LandSlope
# <type 'str'> : replaced with mode
# column name:  Neighborhood
# <type 'str'> : replaced with mode
# column name:  Condition1
# <type 'str'> : replaced with mode
# column name:  Condition2
# <type 'str'> : replaced with mode
# column name:  BldgType
# <type 'str'> : replaced with mode
# column name:  HouseStyle
# ...

# %%
# export dataframe to local disk
df_train.to_csv("F:/House Pricing/data/train_replace_na.csv", index= False)
df_train.to_csv("F:/House Pricing/data/test_replace_na.csv", index= False)
